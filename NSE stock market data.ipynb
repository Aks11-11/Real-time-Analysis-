# %%
pip install nselib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nselib
from nselib import capital_market

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate    weekDay  \
# 0                          Corporate Bonds  22-Jan-2024     Monday
# 1                          Corporate Bonds  26-Jan-2024     Friday
# 2                          Corporate Bonds  19-Feb-2024     Monday
# 3                          Corporate Bonds  08-Mar-2024     Friday
# 4                          Corporate Bonds  25-Mar-2024     Monday
# ..                                     ...          ...        ...
# 16  Securities Lending & Borrowing Schemes  12-Oct-2024   Saturday
# 17  Securities Lending & Borrowing Schemes  01-Nov-2024     Friday
# 18  Securities Lending & Borrowing Schemes  02-Nov-2024   Saturday
# 19  Securities Lending & Borrowing Schemes  15-Nov-2024     Friday
# 20  Securities Lending & Borrowing Schemes  25-Dec-2024  Wednesday
#
#                            description Sr_no
# 0                      Special Holiday     1
# 1                         Republic Day     2
# ...

# %%
capital_market.bhav_copy_equities('05-05-2024')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 capital_market.bhav_copy_equities('05-05-2024')
#
# File /opt/anaconda3/lib/python3.11/site-packages/nselib/capital_market/capital_market_data.py:432, in bhav_copy_equities(trade_date)
#     430 elif request_bhav.status_code == 403:
#     431     raise FileNotFoundError(f' Data not found, change the date...')
# --> 432 bhav_df = bhav_df[['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST', 'PREVCLOSE', 'TOTTRDQTY',
#     433                    'TOTTRDVAL', 'TIMESTAMP', 'TOTALTRADES']]
#     434 return bhav_df
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...

# %%
capital_market.bhav_copy_with_delivery('05-05-2024')
# Out:
#           SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0     1018GS2026     GS      110.15      113.00     110.15       112.10
# 1      20MICRONS     EQ      172.45      173.15     169.00       170.15
# 2     21STCENMGM     BE       52.65       52.65      52.60        52.60
# 3         360ONE     EQ      778.50      796.35     768.05       791.95
# 4      3IINFOLTD     EQ       38.80       39.35      38.35        38.90
# ...          ...    ...         ...         ...        ...          ...
# 2683        ZOTA     EQ      487.95      492.00     484.55       488.40
# 2684       ZUARI     EQ      194.20      195.70     189.00       189.40
# 2685    ZUARIIND     EQ      345.35      348.00     325.15       327.65
# 2686   ZYDUSLIFE     EQ      994.45      999.75     978.30       997.40
# 2687   ZYDUSWELL     EQ     1671.05     1694.95    1661.75      1670.50
#
#       PREV_CLOSE  TTL_TRD_QNTY  TURNOVER_LACS  NO_OF_TRADES DELIV_QTY  \
# ...

# %%
capital_market.block_deals_data(period= '1M')
# Out:
#     Date      Symbol               SecurityName  \
# 0    NaN   JINDALSAW         Jindal Saw Limited
# 1    NaN   JINDALSAW         Jindal Saw Limited
# 2    NaN   JINDALSAW         Jindal Saw Limited
# 3    NaN   JINDALSAW         Jindal Saw Limited
# 4    NaN   JINDALSAW         Jindal Saw Limited
# ..   ...         ...                        ...
# 149  NaN  STARHEALTH  Star Health & Al Ins Co L
# 150  NaN   LUMAXTECH  Lumax Auto Technologies L
# 151  NaN   LUMAXTECH  Lumax Auto Technologies L
# 152  NaN         HGS    Hinduja Global Sols Ltd
# 153  NaN         HGS    Hinduja Global Sols Ltd
#
#                                ClientName Buy/Sell QuantityTraded  \
# 0                         CRESTA FUND LTD     SELL       4,15,000
# 1    ITI MUTUAL FUND(ELSS TAX SAVER FUND)      BUY         15,000
# 2         ITI MUTUAL FUND(ITI VALUE FUND)      BUY         60,000
# 3            ITI MUTUAL FUND(MIDCAP FUND)      BUY       1,40,000
# ...

# %%
capital_market.deliverable_position_data('SBIN',period='1M')
# Out:
#    Symbol Series         Date TradedQty DeliverableQty %DlyQttoTradedQty  \
# 0     NaN     EQ  06-May-2024       NaN            NaN               NaN
# 1     NaN     EQ  07-May-2024       NaN            NaN               NaN
# 2     NaN     EQ  08-May-2024       NaN            NaN               NaN
# 3     NaN     EQ  09-May-2024       NaN            NaN               NaN
# 4     NaN     EQ  10-May-2024       NaN            NaN               NaN
# 5     NaN     EQ  13-May-2024       NaN            NaN               NaN
# 6     NaN     EQ  14-May-2024       NaN            NaN               NaN
# 7     NaN     EQ  15-May-2024       NaN            NaN               NaN
# 8     NaN     EQ  16-May-2024       NaN            NaN               NaN
# 9     NaN     EQ  17-May-2024       NaN            NaN               NaN
# 10    NaN     EQ  18-May-2024       NaN            NaN               NaN
# 11    NaN     EQ  21-May-2024       NaN            NaN               NaN
# ...

# %%
capital_market.price_volume_and_deliverable_position_data('SBIN',period = '1M')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nselib/capital_market/capital_market_data.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#    Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0     NaN     EQ  06-May-2024     831.45     835.00     836.00    803.00
# 1     NaN     EQ  07-May-2024     807.80     812.00     814.65    793.20
# 2     NaN     EQ  08-May-2024     801.90     802.60     822.00    799.50
# 3     NaN     EQ  09-May-2024     810.80     811.90     839.65    803.55
# 4     NaN     EQ  10-May-2024     819.80     827.00     832.05    815.60
# 5     NaN     EQ  13-May-2024     817.35     819.85     819.85    798.60
# ...

# %%
capital_market.price_volume_data('SBIN',period='1M')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nselib/capital_market/capital_market_data.py:86: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#    Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0     NaN     EQ  06-May-2024     831.45     835.00     836.00    803.00
# 1     NaN     EQ  07-May-2024     807.80     812.00     814.65    793.20
# 2     NaN     EQ  08-May-2024     801.90     802.60     822.00    799.50
# 3     NaN     EQ  09-May-2024     810.80     811.90     839.65    803.55
# 4     NaN     EQ  10-May-2024     819.80     827.00     832.05    815.60
# 5     NaN     EQ  13-May-2024     817.35     819.85     819.85    798.60
# ...

# %%
capital_market.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1982        ZOTA                  Zota Health Care LImited      EQ
# 1983       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1984    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1985   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1986   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# ...

# %%
capital_market.fno_equity_list()

# %%
capital_market.india_vix_data(period = '1M')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nselib/capital_market/capital_market_data.py:182: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#       TIMESTAMP INDEX_NAME  OPEN_INDEX_VAL  CLOSE_INDEX_VAL  HIGH_INDEX_VAL  \
# 0   06-MAY-2024  INDIA VIX         14.6175          16.6000         16.9625
# 1   07-MAY-2024  INDIA VIX         16.6000          17.0075         17.6425
# 2   08-MAY-2024  INDIA VIX         17.0075          17.0800         18.3175
# 3   09-MAY-2024  INDIA VIX         17.0800          18.2000         19.1725
# 4   10-MAY-2024  INDIA VIX         18.2000          18.4725         19.0075
# 5   13-MAY-2024  INDIA VIX         18.4725          20.6000         21.4850
# ...

# %%
capital_market.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1982        ZOTA                  Zota Health Care LImited      EQ
# 1983       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1984    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1985   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1986   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# ...
